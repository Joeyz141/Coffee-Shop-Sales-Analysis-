# %% [markdown]
# # ☕ Coffee Shop Sales Analysis Dashboard
#
# ## Project Overview
#
# In this project we explore coffee shop sales in three locations to understand customer relations with coffee shop products. We look at the revenue generated and transactions purchased over time to better understand customer demands. In this process we use Excel to prepare the data for analysis, then explore the data with pivot tables, and lastly build a dynamic dashboard. We then finalize our dashboard in PowerBI and add additional metrics and filters so that stakeholders can interact and analyze KPIs, sales trends, and product performance.
#
# Overall, for coffee shop stakeholders to make beneficial business decisions, we use data-driven insights to help analyze and understand the business to increase its revenue through its strengths and weaknesses showcased via data in our interactive dashboard.
#
# ---
#
# # Business Problem
#
# Coffee shops need better visibility into sales performance across locations, products, and time periods. These factors are needed in making the right business decisions for stakeholders.
#
# ---
#
#
# # Data Preparation in Excel
#
# - Utilized feature engineering to create new fields that give us columns **Revenue** (price * quantity), columns **Month** and **Day of the week** based on transaction_date, and columns **Hour** extracted from transaction_date.
#
# ---
#
# # Exploratory Analysis Using Pivot Tables
#
# - Pivot tables were created and used to identify key sales patterns across time and product catgories, revealing strong seasonal trends and highlighting which products drive the majority of transactions. These insights gave the foundation in building an interactive dashboard in Excel to monitor sales performance and make informed operational decisions.
#
#
#
# ---
#
# # Dynamic Dashboard in Excel
#
#
# ![Excel Dashboard](images/excel_dashboard.png)
#
# - These interactive graphs allows us to now see a visualization of our sales performance across our three coffee shop locations.
#
# ---
#
# # Power BI Dashboard
#
# ![PowerBI Dashboard](images/coffee_shop_dashboard.png)
#
# - I utilized PowerBI and pulled data from the Excel dashboard to scale real-time information and allow for faster and improved reporting times. In PowerBI we added new features such as Total Items Sold, Average Revnue per Item, and Peak Sales Hour to show key performance indicators. A Product Categories filter in addition was added to analyze revenue and items sold to increase sales performance interactions with our dashboard.
#
#
# ---
#
# # Key Insights
#
# ### Weekday Demand is Higher
# - Sales activity is consistently higher on weekdays compared to weekends, indicating strong demand from commuters.
#
# ### Astoria Store Performs Efficiently
#
# - Astoria opens from **7AM to 7PM,** but other stores operate from 6AM to 8PM. However, Astoria still generates the **second highest revenue**, meaning Astoria operates more **efficiently** with its sales.
#
# ### Winter Season Sales Dip
#
# - Monthly revenue showcases **January** & **February** having a noticeable dip in sales, followed by growth in sales from March to June.
#
# ### Lower Manhattan Evening Demand is Low
#
# - After **7pm**, the lower manhattan location experiences minimal sales indicating there is a low evening demand compared to other stores.
#
#
# ### Morning Rush Drives Demand
# - There is high demand from the hours of **7AM to 10AM**, suggesting strong morning commuter traffic.
#
# ---
#
# # Business Recommendations
#
# ### 1. Adjust Lower Manhattan Store Hours
#
# - Closing the Manhattan store at **7pm** could reduce operational costs without revenue being affected.
#
# ### 2. Increase Morning Staffing
#
# - An increase in morning staff from **7AM-10AM** could increase customer satisfication in meeting strong commuter traffic demand.
#
# ### 3. Introduce Winter Promotions
#
# - Introduce winter promotions to stimulate more traffic during slow winter periods.
#
# ### 4. Increase Budgets for Coffee & Tea
#
# - Increase budgets for Coffee & Tea to expand on it's menu, and lower budgeting with product categories that bring less revenue in.
#
# ---
#
# # Skills Demonstrated
#
# This project demonstrates the following data analytics skills:
#
# - Data cleaning and preparation in **Excel**
# - Exploratory Data Analysis using **Pivot Tables**
# - Data Visualization and dashboard design
# - Development of **interactive Power BI dashboards**
# - Business insight & translating findings into **operational recommendations**
# ---
#
# # Author
#
# Joseph Yewhalashet
